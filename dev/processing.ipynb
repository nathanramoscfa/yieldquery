# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from utils.processing import process_data

# %%
df = process_data()
df
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0506
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0440
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0565
# MUB                        iShares National Muni Bond ETF             0.0348
# IEF                   iShares 7-10 Year Treasury Bond ETF             0.0422
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0545
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0590
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0578
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0436
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0459
#
#               Date
# Ticker
# ...

# %%
df.sort_values(by='Yield to Maturity', ascending=False)
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# PGHY        Invesco Global Short Term High Yield Bond ETF             0.1022
# JBBB                                        B-BBB CLO ETF             0.0975
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0963
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0960
# BKLN                              Invesco Senior Loan ETF             0.0947
# ...                                                   ...                ...
# BBIP         JPMorgan BetaBuilders U.S. TIPS 0-5 Year ETF             0.0254
# TIP                                 iShares TIPS Bond ETF             0.0237
# PBTP                 Invesco PureBeta℠ 0-5 Yr US TIPS ETF             0.0218
# CWB            SPDR® Bloomberg Convertible Securities ETF             0.0181
# DFIP                   Inflation Protected Securities ETF             0.0177
#
#               Date
# Ticker
# ...

# %%
df.to_csv('../data/bond_etf_yield.csv')
df.to_csv('../../cape/data/bond_etf_yield.csv')
