# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from utils.processing import process_data

# %%
df = process_data()
df
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0502
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0439
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0562
# MUB                        iShares National Muni Bond ETF             0.0346
# IEF                   iShares 7-10 Year Treasury Bond ETF             0.0420
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0540
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0581
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0574
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0432
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0453
#
#               Date
# Ticker
# AGG     08-11-2023
# TLT     08-11-2023
# LQD     08-11-2023
# MUB     08-11-2023
# IEF     08-11-2023
# ...            ...
# MBSD    08-11-2023
# RAVI    08-11-2023
# SKOR    08-11-2023
# TDTF    08-11-2023
# TDTT    08-11-2023
#
# [287 rows x 3 columns]

# %%
df.sort_values(by='Yield to Maturity', ascending=False)
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# PGHY        Invesco Global Short Term High Yield Bond ETF             0.1022
# JBBB                                        B-BBB CLO ETF             0.1001
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0961
# BRLN                     BlackRock Floating Rate Loan ETF             0.0948
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0948
# ...                                                   ...                ...
# GDEF                   Goldman Sachs Defensive Equity ETF                NaN
# GPAL    Goldman Sachs ActiveBeta Paris-Aligned Climate...                NaN
# GINN                    Goldman Sachs Innovate Equity ETF                NaN
# GSIE    Goldman Sachs ActiveBeta International Equity ETF                NaN
# GCLN      Goldman Sachs Bloomberg Clean Energy Equity ETF                NaN
#
#               Date
# Ticker
# PGHY    08-11-2023
# JBBB    08-11-2023
# HYGV    08-11-2023
# BRLN    08-11-2023
# EMHY    08-11-2023
# ...            ...
# GDEF    08-11-2023
# GPAL    08-11-2023
# GINN    08-11-2023
# GSIE    08-11-2023
# GCLN    08-11-2023
#
# [287 rows x 3 columns]

# %%
df.to_csv('../data/bond_etf_yield.csv')
