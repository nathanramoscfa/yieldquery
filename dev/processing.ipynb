# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from utils.processing import process_data

# %%
df = process_data()
df
# Out:
#   1%|▉                                                                                 | 4/333 [00:00<00:22, 14.37it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#   7%|█████▎                                                                           | 22/333 [00:01<00:14, 22.14it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████████| 333/333 [00:15<00:00, 21.06it/s]
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0460
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0420
# MUB                        iShares National Muni Bond ETF             0.0305
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0512
# MBB                                       iShares MBS ETF             0.0472
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0493
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0581
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0522
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0396
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0408
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# AGG                  0.0411           0.17                  -0.41      21.74
# TLT                  0.1103           0.03                  -0.71      23.81
# MUB                  0.0307          -0.28                  -1.37      32.79
# LQD                  0.0541           0.22                  -0.30      19.53
# MBB                  0.0471           0.17                  -0.41      21.19
# ...                     ...            ...                    ...        ...
# MBSD                 0.0608           0.17                  -0.41      20.28
# RAVI                 0.0307           0.62                   0.55      17.21
# SKOR                 0.0320           0.41                   0.10      19.16
# TDTF                 0.0328           0.02                  -0.73      25.25
# TDTT                 0.0252           0.07                  -0.62      24.51
#
#               Date
# Ticker
# AGG     01-02-2024
# TLT     01-02-2024
# MUB     01-02-2024
# LQD     01-02-2024
# MBB     01-02-2024
# ...            ...
# MBSD    01-02-2024
# RAVI    01-02-2024
# SKOR    01-02-2024
# TDTF    01-02-2024
# TDTT    01-02-2024
#
# [333 rows x 7 columns]

# %%
df.sort_values(by='Yield to Maturity', ascending=False)
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# BRLN                     BlackRock Floating Rate Loan ETF             0.0933
# JBBB                                        B-BBB CLO ETF             0.0918
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0907
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0900
# HYGH     iShares Interest Rate Hedged High Yield Bond ETF             0.0888
# ...                                                   ...                ...
# IBMQ         iShares® iBonds® Dec 2028 Term Muni Bond ETF             0.0241
# IBMR         iShares® iBonds® Dec 2029 Term Muni Bond ETF             0.0235
# DFIP                   Inflation Protected Securities ETF             0.0220
# CWB            SPDR® Bloomberg Convertible Securities ETF             0.0182
# WTBN                  WisdomTree Bianco Total Return Fund             0.0000
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# BRLN                 0.0360           1.51                   2.46      10.72
# JBBB                 0.0579           0.91                   1.17      10.89
# EMHY                 0.0481           1.07                   1.51      11.03
# HYGV                 0.0507           1.00                   1.36      11.11
# HYGH                 0.0585           0.85                   1.04      11.26
# ...                     ...            ...                    ...        ...
# IBMQ                 0.0250          -0.60                  -2.06      41.49
# IBMR                 0.0242          -0.64                  -2.14      42.55
# DFIP                 0.0484          -0.35                  -1.52      45.45
# CWB                  0.0632          -0.33                  -1.48      54.95
# WTBN                 0.0279          -1.40                  -3.77        inf
#
#               Date
# Ticker
# BRLN    01-02-2024
# JBBB    01-02-2024
# EMHY    01-02-2024
# HYGV    01-02-2024
# HYGH    01-02-2024
# ...            ...
# IBMQ    01-02-2024
# IBMR    01-02-2024
# DFIP    11-30-2023
# CWB     01-02-2024
# WTBN    01-02-2024
#
# [333 rows x 7 columns]

# %%
df.to_csv('../data/bond_etf_yield.csv')

# %%
df.loc['AGG']
# Out:
# Name                     iShares Core U.S. Aggregate Bond ETF
# Yield to Maturity                                       0.046
# Downside Volatility                                    0.0411
# Sortino Ratio                                            0.17
# Sortino Ratio Z-Score                                   -0.41
# P/E Ratio                                               21.74
# Date                                               01-02-2024
# Name: AGG, dtype: object
