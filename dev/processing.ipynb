# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from utils.processing import process_data

# %%
df = process_data()
df
# Out:
#  45%|████████████████████████████████████▍                                           | 161/354 [00:18<00:21,  8.84it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  69%|███████████████████████████████████████████████████████▌                        | 246/354 [00:29<00:10, 10.41it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  88%|██████████████████████████████████████████████████████████████████████▌         | 312/354 [00:36<00:04,  8.95it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  93%|██████████████████████████████████████████████████████████████████████████▌     | 330/354 [00:38<00:02,  8.64it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████████| 354/354 [00:41<00:00,  8.56it/s]
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0484
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0444
# MUB                        iShares National Muni Bond ETF             0.0340
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0526
# MBB                                       iShares MBS ETF             0.0501
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0491
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0571
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0531
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0424
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0439
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# AGG                  0.0544           0.05                  -0.22      20.66
# TLT                  0.1081          -0.01                  -0.37      22.52
# MUB                  0.0307          -0.38                  -1.29      29.41
# LQD                  0.0677           0.10                  -0.09      19.01
# MBB                  0.0940           0.05                  -0.22      19.96
# ...                     ...            ...                    ...        ...
# MBSD                 0.0574           0.06                  -0.19      20.37
# RAVI                 0.0307           0.37                   0.58      17.51
# SKOR                 0.0481           0.16                   0.06      18.83
# TDTF                 0.0486          -0.07                  -0.52      23.58
# TDTT                 0.0300          -0.06                  -0.49      22.78
#
#               Date
# Ticker
# AGG     03-28-2024
# TLT     03-28-2024
# MUB     03-28-2024
# LQD     03-28-2024
# MBB     03-28-2024
# ...            ...
# MBSD    03-28-2024
# RAVI    03-28-2024
# SKOR    03-28-2024
# TDTF    03-28-2024
# TDTT    03-28-2024
#
# [354 rows x 7 columns]

# %%
df.sort_values(by='Yield to Maturity', ascending=False)
# Out:
#                                                 Name  Yield to Maturity  \
# Ticker
# BKLN                         Invesco Senior Loan ETF             0.0932
# JBBB                                   B-BBB CLO ETF             0.0902
# SRLN                SPDR® Blackstone Senior Loan ETF             0.0884
# HYEM     VanEck Emerging Markets High Yield Bond ETF             0.0867
# BRLN                BlackRock Floating Rate Loan ETF             0.0867
# ...                                              ...                ...
# IBMR    iShares® iBonds® Dec 2029 Term Muni Bond ETF             0.0268
# PBTP                      Invesco 0-5 Yr US TIPS ETF             0.0237
# DFIP              Inflation Protected Securities ETF             0.0194
# CWB       SPDR® Bloomberg Convertible Securities ETF             0.0187
# BBIP    JPMorgan BetaBuilders U.S. TIPS 0-5 Year ETF             0.0180
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# BKLN                 0.0344           1.38                   3.09      10.73
# JBBB                 0.0445           1.00                   2.14      11.09
# SRLN                 0.0360           1.19                   2.62      11.31
# HYEM                 0.0856           0.48                   0.85      11.53
# BRLN                 0.0353           1.16                   2.54      11.53
# ...                     ...            ...                    ...        ...
# IBMR                 0.0233          -0.81                  -2.36      37.31
# PBTP                 0.0270          -0.81                  -2.36      42.19
# DFIP                 0.1151          -0.23                  -0.91      51.55
# CWB                  0.0548          -0.49                  -1.56      53.48
# BBIP                 0.0391          -0.71                  -2.11      55.56
#
#               Date
# Ticker
# BKLN    04-05-2024
# JBBB    03-28-2024
# SRLN    03-28-2024
# HYEM    04-10-2024
# BRLN    03-28-2024
# ...            ...
# IBMR    03-28-2024
# PBTP    04-05-2024
# DFIP    02-29-2024
# CWB     03-28-2024
# BBIP    02-29-2024
#
# [354 rows x 7 columns]

# %%
df.to_csv('../data/bond_etf_yield.csv')

# %%
df.loc['AGG']
# Out:
# Name                     iShares Core U.S. Aggregate Bond ETF
# Yield to Maturity                                      0.0484
# Downside Volatility                                    0.0544
# Sortino Ratio                                            0.05
# Sortino Ratio Z-Score                                   -0.22
# P/E Ratio                                               20.66
# Date                                               03-28-2024
# Name: AGG, dtype: object
