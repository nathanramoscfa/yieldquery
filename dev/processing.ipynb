# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from utils.processing import process_data

# %%
df = process_data()
df
# Out:
#   8%|██████▎                                                                          | 22/282 [00:01<00:11, 22.40it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  86%|████████████████████████████████████████████████████████████████████▉           | 243/282 [00:12<00:01, 22.55it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  92%|█████████████████████████████████████████████████████████████████████████▍      | 259/282 [00:12<00:01, 22.17it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████████| 282/282 [00:14<00:00, 20.11it/s]
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0488
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0443
# MUB                        iShares National Muni Bond ETF             0.0332
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0540
# MBB                                       iShares MBS ETF             0.0505
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0531
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0592
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0555
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0422
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0432
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# AGG                  0.0530           0.14                  -0.51      20.49
# TLT                  0.1140           0.03                  -0.74      22.57
# MUB                  0.0306          -0.26                  -1.32      30.12
# LQD                  0.0576           0.22                  -0.35      18.52
# MBB                  0.0462           0.20                  -0.39      19.80
# ...                     ...            ...                    ...        ...
# MBSD                 0.0561           0.21                  -0.37      18.83
# RAVI                 0.0297           0.61                   0.43      16.89
# SKOR                 0.0303           0.47                   0.15      18.02
# TDTF                 0.0366           0.03                  -0.74      23.70
# TDTT                 0.0273           0.07                  -0.65      23.15
#
#               Date
# Ticker
# AGG     12-05-2023
# TLT     12-05-2023
# MUB     12-05-2023
# LQD     12-05-2023
# MBB     12-05-2023
# ...            ...
# MBSD    12-05-2023
# RAVI    12-05-2023
# SKOR    12-05-2023
# TDTF    12-05-2023
# TDTT    12-05-2023
#
# [282 rows x 7 columns]

# %%
df.sort_values(by='Yield to Maturity', ascending=False)
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0965
# JBBB                                        B-BBB CLO ETF             0.0965
# BRLN                     BlackRock Floating Rate Loan ETF             0.0954
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0953
# BBHY    JPMorgan BetaBuilders USD High Yield Corporate...             0.0949
# ...                                                   ...                ...
# IBMP         iShares® iBonds® Dec 2027 Term Muni Bond ETF             0.0273
# IBMR         iShares® iBonds® Dec 2029 Term Muni Bond ETF             0.0270
# IBMQ         iShares® iBonds® Dec 2028 Term Muni Bond ETF             0.0268
# DFIP                   Inflation Protected Securities ETF             0.0256
# CWB            SPDR® Bloomberg Convertible Securities ETF             0.0184
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# HYGV                 0.0521           1.06                   1.34      10.36
# JBBB                 0.0827           0.67                   0.55      10.36
# BRLN                 0.0369           1.47                   2.16      10.48
# EMHY                 0.0555           0.97                   1.15      10.49
# BBHY                 0.0405           1.33                   1.88      10.54
# ...                     ...            ...                    ...        ...
# IBMP                 0.0240          -0.58                  -1.96      36.63
# IBMR                 0.0227          -0.63                  -2.06      37.04
# IBMQ                 0.0261          -0.55                  -1.90      37.31
# DFIP                 0.0478          -0.33                  -1.46      39.06
# CWB                  0.0535          -0.43                  -1.66      54.35
#
#               Date
# Ticker
# HYGV    12-05-2023
# JBBB    12-05-2023
# BRLN    12-05-2023
# EMHY    12-05-2023
# BBHY    10-31-2023
# ...            ...
# IBMP    12-05-2023
# IBMR    12-05-2023
# IBMQ    12-05-2023
# DFIP    10-31-2023
# CWB     12-05-2023
#
# [282 rows x 7 columns]

# %%
df.to_csv('../data/bond_etf_yield.csv')

# %%
df.loc['AGG']
# Out:
# Name                     iShares Core U.S. Aggregate Bond ETF
# Yield to Maturity                                      0.0488
# Downside Volatility                                     0.053
# Sortino Ratio                                            0.14
# Sortino Ratio Z-Score                                   -0.51
# P/E Ratio                                               20.49
# Date                                               12-05-2023
# Name: AGG, dtype: object
