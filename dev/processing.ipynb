# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from utils.processing import process_data

# %%
df = process_data()
df
# Out:
#   7%|█████▎                                                                           | 22/337 [00:01<00:15, 20.55it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#  44%|██████████████████████████████████▉                                             | 147/337 [00:07<00:09, 20.28it/s]C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# C:\Users\25del\anaconda3\envs\nrcapital\Lib\site-packages\arch\univariate\base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████████| 337/337 [00:16<00:00, 20.20it/s]
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0486
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0438
# MUB                        iShares National Muni Bond ETF             0.0326
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0537
# MBB                                       iShares MBS ETF             0.0500
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0524
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0589
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0554
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0417
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0430
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# AGG                  0.0504           0.12                  -0.39      20.58
# TLT                  0.1124           0.01                  -0.59      22.83
# MUB                  0.0306          -0.33                  -1.22      30.67
# LQD                  0.0558           0.20                  -0.25      18.62
# MBB                  0.0439           0.16                  -0.32      20.00
# ...                     ...            ...                    ...        ...
# MBSD                 0.0519           0.18                  -0.28      19.08
# RAVI                 0.0311           0.52                   0.34      16.98
# SKOR                 0.0318           0.40                   0.12      18.05
# TDTF                 0.0319          -0.03                  -0.67      23.98
# TDTT                 0.0259           0.01                  -0.59      23.26
#
#               Date
# Ticker
# AGG     12-07-2023
# TLT     12-07-2023
# MUB     12-07-2023
# LQD     12-07-2023
# MBB     12-07-2023
# ...            ...
# MBSD    12-08-2023
# RAVI    12-08-2023
# SKOR    12-08-2023
# TDTF    12-08-2023
# TDTT    12-08-2023
#
# [337 rows x 7 columns]

# %%
df.sort_values(by='Yield to Maturity', ascending=False)
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0965
# BRLN                     BlackRock Floating Rate Loan ETF             0.0954
# JBBB                                        B-BBB CLO ETF             0.0952
# BBHY    JPMorgan BetaBuilders USD High Yield Corporate...             0.0949
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0947
# ...                                                   ...                ...
# DFIP                   Inflation Protected Securities ETF             0.0256
# IBMR         iShares® iBonds® Dec 2029 Term Muni Bond ETF             0.0250
# PVI            Invesco Floating Rate Municipal Income ETF             0.0240
# CWB            SPDR® Bloomberg Convertible Securities ETF             0.0184
# BSMN         Invesco BulletShares 2023 Municipal Bond ETF             0.0015
#
#         Downside Volatility  Sortino Ratio  Sortino Ratio Z-Score  P/E Ratio  \
# Ticker
# HYGV                 0.0492           1.09                   1.38      10.36
# BRLN                 0.0367           1.43                   2.00      10.48
# JBBB                 0.0765           0.68                   0.63      10.50
# BBHY                 0.0369           1.41                   1.97      10.54
# EMHY                 0.0552           0.94                   1.11      10.56
# ...                     ...            ...                    ...        ...
# DFIP                 0.0460          -0.37                  -1.29      39.06
# IBMR                 0.0225          -0.79                  -2.06      40.00
# PVI                  0.0086          -2.19                  -4.62      41.67
# CWB                  0.0527          -0.46                  -1.45      54.35
# BSMN                 0.0134          -3.08                  -6.25     666.67
#
#               Date
# Ticker
# HYGV    12-08-2023
# BRLN    12-07-2023
# JBBB    12-08-2023
# BBHY    10-31-2023
# EMHY    12-07-2023
# ...            ...
# DFIP    10-31-2023
# IBMR    12-07-2023
# PVI     12-07-2023
# CWB     12-07-2023
# BSMN    12-07-2023
#
# [337 rows x 7 columns]

# %%
df.to_csv('../data/bond_etf_yield.csv')

# %%
df.loc['AGG']
# Out:
# Name                     iShares Core U.S. Aggregate Bond ETF
# Yield to Maturity                                      0.0486
# Downside Volatility                                    0.0504
# Sortino Ratio                                            0.12
# Sortino Ratio Z-Score                                   -0.39
# P/E Ratio                                               20.58
# Date                                               12-07-2023
# Name: AGG, dtype: object
