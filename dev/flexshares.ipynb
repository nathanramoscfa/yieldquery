# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import utils.tools as tools
from bots.flexshares import flexshares_bot

# Get DataFrame from vanguard_bot
df = flexshares_bot(return_df=True, headless=False)

# Get the current working directory
current_dir = os.getcwd()

# Find the project root directory
project_dir = tools.find_project_root(current_dir)

# Construct the path to the 'data' directory
data_dir = os.path.join(project_dir, 'data')

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'flexshares.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading FlexShares ETF yield data...
# ['https://www.flexshares.com/us/en/individual/funds/bndc', 'https://www.flexshares.com/us/en/individual/funds/feig', 'https://www.flexshares.com/us/en/individual/funds/hygv', 'https://www.flexshares.com/us/en/individual/funds/lkor', 'https://www.flexshares.com/us/en/individual/funds/mbsd', 'https://www.flexshares.com/us/en/individual/funds/ravi', 'https://www.flexshares.com/us/en/individual/funds/skor', 'https://www.flexshares.com/us/en/individual/funds/tdtf', 'https://www.flexshares.com/us/en/individual/funds/tdtt']
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [01:18<00:00,  8.73s/it]
# Saving FlexShares ETF yield data to CSV file...
# Done!
#                                                      NAME  AS OF DATE  \
# TICKER
# BNDC                     FLEXSHARES CORE SELECT BOND FUND  01-02-2024
# FEIG    FLEXSHARES ESG & CLIMATE INVESTMENT GRADE CORP...  01-02-2024
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...  01-02-2024
# LKOR    FLEXSHARES CREDIT-SCORED US LONG CORPORATE BON...  01-02-2024
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND  01-02-2024
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND  01-02-2024
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...  01-02-2024
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...  01-02-2024
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...  01-02-2024
#
#            MARKET PRICE 52-WEEK-HIGH 52-WEEK LOW NAV PRICE PREMIUM/DISCOUNT  \
# TICKER
# BNDC    $22.26 (-0.49%)       $23.75      $20.61    $22.26          0.0148%
# FEIG    $41.38 (-0.58%)       $42.23      $37.70    $41.25          0.3188%
# HYGV    $40.78 (-0.22%)       $42.04      $38.42    $40.80         -0.0569%
# LKOR    $44.26 (-0.96%)       $46.25      $37.76    $44.28         -0.0185%
# MBSD    $20.45 (-0.52%)       $21.05      $19.32    $20.47         -0.0660%
# RAVI     $75.04 (0.01%)       $75.29      $74.39    $75.05         -0.0180%
# SKOR    $47.78 (-0.40%)       $48.06      $45.16    $47.69          0.1835%
# TDTF    $23.61 (-0.08%)       $24.63      $22.53    $23.59          0.0767%
# TDTT    $23.61 (-0.04%)       $24.24      $22.96    $23.58          0.0963%
#
#        PRIMARY EXCHANGE      CUSIP TOTAL NET ASSETS  ...  \
# TICKER                                               ...
# BNDC          NYSE Arca  33939L670         $182.54M  ...
# FEIG          NYSE Arca  33939L571          $30.93M  ...
# HYGV          NYSE Arca  33939L662           $1.41B  ...
# LKOR               CBOE  33939L753          $33.21M  ...
# MBSD          NYSE Arca  33939L779          $75.73M  ...
# RAVI          NYSE Arca  33939L886           $1.10B  ...
# SKOR             NASDAQ  33939L761         $312.35M  ...
# TDTF          NYSE Arca  33939L605         $832.61M  ...
# TDTT          NYSE Arca  33939L506           $1.83B  ...
#
#        WEIGHTED AVG OPTION ADJUSTED SPREAD   INCEPTION WEIGHTED AVG MATURITY  \
# TICKER
# BNDC                             63.49 bps  11/18/2016                   NaN
# FEIG                                   NaN  09/20/2021             11.61 yrs
# HYGV                                   NaN  07/17/2018              5.25 yrs
# LKOR                                   NaN  09/23/2015             23.46 yrs
# MBSD                                   NaN  09/03/2014                   NaN
# RAVI                                   NaN  10/09/2012                   NaN
# SKOR                                   NaN  11/12/2014              5.77 yrs
# TDTF                                   NaN  09/19/2011              5.91 yrs
# TDTT                                   NaN  09/19/2011              3.52 yrs
#
#        NAIC DESIGNATION WEIGHTED AVG COUPON FLOATING RATE FIXED RATE  \
# TICKER
# BNDC                NaN                 NaN           NaN        NaN
# FEIG                NaN                 NaN           NaN        NaN
# HYGV                Yes                 NaN           NaN        NaN
# LKOR                NaN                 NaN           NaN        NaN
# MBSD                NaN              0.0362           NaN        NaN
# RAVI                Yes                 NaN        31.96%     63.20%
# SKOR                NaN                 NaN           NaN        NaN
# TDTF                Yes                 NaN           NaN        NaN
# TDTT                Yes                 NaN           NaN        NaN
#
#        ZERO RATE WEIGHTED AVG NOMINAL YIELD  MODIFIED ADJUSTED DURATION
# TICKER
# BNDC         NaN                        NaN                         NaN
# FEIG         NaN                        NaN                         NaN
# HYGV         NaN                        NaN                         NaN
# LKOR         NaN                        NaN                         NaN
# MBSD         NaN                        NaN                         NaN
# RAVI       4.84%                        NaN                         NaN
# SKOR         NaN                        NaN                         NaN
# TDTF         NaN                     0.0396                    5.05 yrs
# TDTT         NaN                     0.0408                    3.13 yrs
#
# [9 rows x 32 columns]
