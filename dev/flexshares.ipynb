# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import utils.tools as tools
from bots.flexshares import flexshares_bot

# Get DataFrame from vanguard_bot
df = flexshares_bot(return_df=True, headless=True)

# Get the current working directory
current_dir = os.getcwd()

# Find the project root directory
project_dir = tools.find_project_root(current_dir)

# Construct the path to the 'data' directory
data_dir = os.path.join(project_dir, 'data')

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'flexshares.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading FlexShares ETF yield data...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [01:18<00:00,  8.77s/it]
# Saving FlexShares ETF yield data to CSV file...
# Done!
#                                                      NAME  AS OF DATE  \
# TICKER
# BNDC                     FLEXSHARES CORE SELECT BOND FUND  12-01-2023
# FEIG    FLEXSHARES ESG & CLIMATE INVESTMENT GRADE CORP...  12-01-2023
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...  12-01-2023
# LKOR    FLEXSHARES CREDIT-SCORED US LONG CORPORATE BON...  12-01-2023
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND  12-01-2023
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND  12-01-2023
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...  12-01-2023
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...  12-01-2023
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...  12-01-2023
#
#            MARKET PRICE 52-WEEK-HIGH 52-WEEK LOW NAV PRICE PREMIUM/DISCOUNT  \
# TICKER
# BNDC     $21.88 (0.90%)       $22.87      $20.61    $21.90         -0.0251%
# FEIG     $40.46 (0.56%)       $42.23      $37.70    $40.30          0.4283%
# HYGV     $40.14 (0.00%)       $42.04      $38.42    $39.89          0.5942%
# LKOR     $42.60 (1.13%)       $46.25      $37.76    $42.52          0.2375%
# MBSD     $20.23 (0.30%)       $21.05      $19.32    $20.23          0.0484%
# RAVI    $74.97 (-0.36%)       $75.29      $74.22    $74.96          0.0049%
# SKOR     $47.07 (0.22%)       $48.77      $45.16    $46.96          0.2493%
# TDTF     $23.25 (0.28%)       $24.63      $22.53    $23.23          0.0693%
# TDTT     $23.40 (0.04%)       $24.24      $22.96    $23.38          0.0594%
#
#        PRIMARY EXCHANGE      CUSIP TOTAL NET ASSETS  ...  \
# TICKER                                               ...
# BNDC          NYSE Arca  33939L670         $185.05M  ...
# FEIG          NYSE Arca  33939L571          $28.21M  ...
# HYGV          NYSE Arca  33939L662           $1.35B  ...
# LKOR               CBOE  33939L753          $31.88M  ...
# MBSD          NYSE Arca  33939L779          $75.86M  ...
# RAVI          NYSE Arca  33939L886           $1.10B  ...
# SKOR             NASDAQ  33939L761         $284.12M  ...
# TDTF          NYSE Arca  33939L605         $828.10M  ...
# TDTT          NYSE Arca  33939L506           $1.90B  ...
#
#        WEIGHTED AVG OPTION ADJUSTED SPREAD   INCEPTION WEIGHTED AVG MATURITY  \
# TICKER
# BNDC                             69.19 bps  11/18/2016                   NaN
# FEIG                                   NaN  09/20/2021             11.31 yrs
# HYGV                                   NaN  07/17/2018              5.32 yrs
# LKOR                                   NaN  09/23/2015             23.42 yrs
# MBSD                                   NaN  09/03/2014                   NaN
# RAVI                                   NaN  10/09/2012                   NaN
# SKOR                                   NaN  11/12/2014              5.70 yrs
# TDTF                                   NaN  09/19/2011              5.95 yrs
# TDTT                                   NaN  09/19/2011              3.47 yrs
#
#        NAIC DESIGNATION WEIGHTED AVG COUPON FLOATING RATE FIXED RATE  \
# TICKER
# BNDC                NaN                 NaN           NaN        NaN
# FEIG                NaN                 NaN           NaN        NaN
# HYGV                Yes                 NaN           NaN        NaN
# LKOR                NaN                 NaN           NaN        NaN
# MBSD                NaN              0.0368           NaN        NaN
# RAVI                Yes                 NaN        32.07%     60.83%
# SKOR                NaN                 NaN           NaN        NaN
# TDTF                Yes                 NaN           NaN        NaN
# TDTT                Yes                 NaN           NaN        NaN
#
#        ZERO RATE WEIGHTED AVG NOMINAL YIELD  MODIFIED ADJUSTED DURATION
# TICKER
# BNDC         NaN                        NaN                         NaN
# FEIG         NaN                        NaN                         NaN
# HYGV         NaN                        NaN                         NaN
# LKOR         NaN                        NaN                         NaN
# MBSD         NaN                        NaN                         NaN
# RAVI       7.03%                        NaN                         NaN
# SKOR         NaN                        NaN                         NaN
# TDTF         NaN                     0.0440                    5.05 yrs
# TDTT         NaN                     0.0449                    3.07 yrs
#
# [9 rows x 32 columns]
