# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import sys
from bots.flexshares import flexshares_bot

# Get DataFrame from vanguard_bot
df = flexshares_bot(return_df=True, headless=True)

# Get the absolute path of the project's root directory
project_dir = os.path.dirname(os.getcwd())

# Change the working directory to the project's root directory
os.chdir(project_dir)

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'flexshares.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading FlexShares ETF yield data...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:33<00:00,  9.35s/it]
# Saving FlexShares ETF yield data to CSV file...
# Done!
#                                                      NAME  AS OF DATE  \
# TICKER
# BNDC                     FLEXSHARES CORE SELECT BOND FUND  08-14-2023
# FEHY    FLEXSHARES ESG & CLIMATE HIGH YIELD CORPORATE ...  07-11-2023
# FEIG    FLEXSHARES ESG & CLIMATE INVESTMENT GRADE CORP...  08-14-2023
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...  08-14-2023
# LKOR    FLEXSHARES CREDIT-SCORED US LONG CORPORATE BON...  08-14-2023
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND  08-14-2023
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND  08-14-2023
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...  08-14-2023
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...  08-14-2023
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...  08-14-2023
#
#            MARKET PRICE 52-WEEK-HIGH 52-WEEK LOW NAV PRICE PREMIUM/DISCOUNT  \
# TICKER
# BNDC    $21.64 (-0.18%)       $23.34      $21.11    $21.63          0.0116%
# FEHY    $40.05 (-0.11%)       $44.00      $39.64    $40.09          0.0002%
# FEIG    $39.83 (-0.07%)       $43.03      $37.85    $39.77          0.1521%
# HYGV    $40.27 (-0.07%)       $43.44      $38.43    $40.29          0.0330%
# LKOR    $41.65 (-0.05%)       $47.15      $38.16    $41.54          0.2908%
# MBSD    $20.06 (-0.10%)       $21.44      $19.72    $20.05          0.0474%
# RAVI     $74.92 (0.03%)       $75.29      $74.07    $74.89          0.0206%
# SKOR    $46.52 (-0.09%)       $48.77      $44.75    $46.44          0.1802%
# TDTF    $23.34 (-0.21%)       $25.70      $23.20    $23.32          0.0356%
# TDTT    $23.35 (-0.21%)       $24.99      $23.18    $23.33          0.0240%
#
#        PRIMARY EXCHANGE      CUSIP TOTAL NET ASSETS  ...  \
# TICKER                                               ...
# BNDC          NYSE Arca  33939L670         $201.72M  ...
# FEHY          NYSE Arca  33939L589           $2.00M  ...
# FEIG          NYSE Arca  33939L571          $37.78M  ...
# HYGV          NYSE Arca  33939L662           $1.20B  ...
# LKOR               CBOE  33939L753          $31.15M  ...
# MBSD          NYSE Arca  33939L779          $72.16M  ...
# RAVI          NYSE Arca  33939L886           $1.04B  ...
# SKOR             NASDAQ  33939L761         $269.35M  ...
# TDTF          NYSE Arca  33939L605         $714.80M  ...
# TDTT          NYSE Arca  33939L506           $1.91B  ...
#
#        WEIGHTED AVG OPTION ADJUSTED SPREAD   INCEPTION WEIGHTED AVG MATURITY  \
# TICKER
# BNDC                             54.12 bps  11/18/2016                   NaN
# FEHY                                   NaN  09/20/2021              0.00 yrs
# FEIG                                   NaN  09/20/2021             11.48 yrs
# HYGV                                   NaN  07/17/2018              5.35 yrs
# LKOR                                   NaN  09/23/2015             24.01 yrs
# MBSD                                   NaN  09/03/2014                   NaN
# RAVI                                   NaN  10/09/2012                   NaN
# SKOR                                   NaN  11/12/2014              5.67 yrs
# TDTF                                   NaN  09/19/2011              6.05 yrs
# TDTT                                   NaN  09/19/2011              3.47 yrs
#
#        NAIC DESIGNATION WEIGHTED AVG COUPON FLOATING RATE FIXED RATE  \
# TICKER
# BNDC                NaN                 NaN           NaN        NaN
# FEHY                NaN                 NaN           NaN        NaN
# FEIG                NaN                 NaN           NaN        NaN
# HYGV                Yes                 NaN           NaN        NaN
# LKOR                NaN                 NaN           NaN        NaN
# MBSD                NaN              0.0353           NaN        NaN
# RAVI                Yes                 NaN        28.93%     49.76%
# SKOR                NaN                 NaN           NaN        NaN
# TDTF                Yes                 NaN           NaN        NaN
# TDTT                Yes                 NaN           NaN        NaN
#
#        ZERO RATE WEIGHTED AVG NOMINAL YIELD  MODIFIED ADJUSTED DURATION
# TICKER
# BNDC         NaN                        NaN                         NaN
# FEHY         NaN                        NaN                         NaN
# FEIG         NaN                        NaN                         NaN
# HYGV         NaN                        NaN                         NaN
# LKOR         NaN                        NaN                         NaN
# MBSD         NaN                        NaN                         NaN
# RAVI      21.31%                        NaN                         NaN
# SKOR         NaN                        NaN                         NaN
# TDTF         NaN                     0.0436                    5.12 yrs
# TDTT         NaN                     0.0459                    3.06 yrs
#
# [10 rows x 32 columns]
