# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import sys
from bots.vanguard import vanguard_bot

# Get DataFrame from vanguard_bot
df = vanguard_bot(return_df=True, headless=True)

# Get the absolute path of the project's root directory
project_dir = os.path.dirname(os.getcwd())

# Change the working directory to the project's root directory
os.chdir(project_dir)

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'vanguard.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading Vanguard ETF yield data...
# Error getting version of chromedriver 115. Retrying with chromedriver 114 (attempt 1/5)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [01:32<00:00,  4.38s/it]
# Saving Vanguard ETF yield data to CSV file...
# Done!
#                                                      Name  Yield to Maturity  \
# Ticker
# VWOB        Vanguard Emerging Markets Government Bond ETF              0.072
# VCEB                 Vanguard ESG U.S. Corporate Bond ETF              0.055
# EDV               Vanguard Extended Duration Treasury ETF              0.040
# BIV                   Vanguard Intermediate-Term Bond ETF              0.045
# VCIT        Vanguard Intermediate-Term Corporate Bond ETF              0.054
# VGIT              Vanguard Intermediate-Term Treasury ETF              0.041
# BLV                           Vanguard Long-Term Bond ETF              0.048
# VCLT                Vanguard Long-Term Corporate Bond ETF              0.054
# VGLT                      Vanguard Long-Term Treasury ETF              0.040
# VMBS              Vanguard Mortgage-Backed Securities ETF              0.046
# BSV                          Vanguard Short-Term Bond ETF              0.050
# VCSH               Vanguard Short-Term Corporate Bond ETF              0.056
# VTIP    Vanguard Short-Term Inflation-Protected Securi...              0.046
# VTES              Vanguard Short-Term Tax-Exempt Bond ETF              0.032
# VGSH                     Vanguard Short-Term Treasury ETF              0.049
# VTEB                         Vanguard Tax-Exempt Bond ETF              0.035
# BND                        Vanguard Total Bond Market ETF              0.048
# VTC                     Vanguard Total Corporate Bond ETF              0.055
# BNDX                Vanguard Total International Bond ETF              0.053
# BNDW                        Vanguard Total World Bond ETF              0.050
# VUSB                        Vanguard Ultra-Short Bond ETF              0.058
#
#              As of
# Ticker
# VWOB    06-30-2023
# VCEB    06-30-2023
# EDV     06-30-2023
# BIV     06-30-2023
# VCIT    06-30-2023
# VGIT    06-30-2023
# BLV     06-30-2023
# VCLT    06-30-2023
# VGLT    06-30-2023
# VMBS    06-30-2023
# BSV     06-30-2023
# VCSH    06-30-2023
# VTIP    06-30-2023
# VTES    06-30-2023
# VGSH    06-30-2023
# VTEB    06-30-2023
# BND     06-30-2023
# VTC     06-30-2023
# BNDX    06-30-2023
# BNDW    06-30-2023
# VUSB    06-30-2023
