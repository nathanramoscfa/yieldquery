# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from scrapers.ishares import ishares_scraper

# %%
df = ishares_scraper(method='xls', return_df=True)
df
# Out:
# ...
# Moving iShares ETF data...
# Loading iShares ETF data...
# Saving iShares ETF data...
# Done.
#                                                      Name  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF
# TLT                    iShares 20+ Year Treasury Bond ETF
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...
# MUB                        iShares National Muni Bond ETF
# IEF                   iShares 7-10 Year Treasury Bond ETF
# ...                                                   ...
# IBMR         iShares® iBonds® Dec 2029 Term Muni Bond ETF
# AGRH    iShares Interest Rate Hedged U.S. Aggregate Bo...
# HYGI         iShares Inflation Hedged High Yield Bond ETF
# IBTO          iShares® iBonds® Dec 2033 Term Treasury ETF
# AGIH     iShares Inflation Hedged U.S. Aggregate Bond ETF
#
#         Net Expense Ratio (%)  Net Assets (USD)   Asset Class Sub Asset Class  \
# Ticker
# ...
