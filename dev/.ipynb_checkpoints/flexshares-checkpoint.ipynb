# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import sys
from bots.flexshares import flexshares_bot

# Get DataFrame from vanguard_bot
df = flexshares_bot(return_df=True, headless=True)

# Get the absolute path of the project's root directory
project_dir = os.path.dirname(os.getcwd())

# Change the working directory to the project's root directory
os.chdir(project_dir)

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'flexshares.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading FlexShares ETF yield data...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:20<00:00,  8.03s/it]
# Saving FlexShares ETF yield data to CSV file...
# Done!
#                                                      NAME  AS OF DATE  \
# TICKER
# BNDC                     FLEXSHARES CORE SELECT BOND FUND  07-28-2023
# FEHY    FLEXSHARES ESG & CLIMATE HIGH YIELD CORPORATE ...  07-11-2023
# FEIG    FLEXSHARES ESG & CLIMATE INVESTMENT GRADE CORP...  07-28-2023
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...  07-28-2023
# LKOR    FLEXSHARES CREDIT-SCORED US LONG CORPORATE BON...  07-28-2023
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND  07-28-2023
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND  07-28-2023
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...  07-28-2023
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...  07-28-2023
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...  07-28-2023
#
#            MARKET PRICE 52-WEEK-HIGH 52-WEEK LOW NAV PRICE PREMIUM/DISCOUNT  \
# TICKER
# BNDC     $22.00 (0.31%)       $23.61      $21.11    $22.00         -0.0173%
# FEHY    $40.05 (-0.11%)       $44.00      $39.64    $40.09          0.0002%
# FEIG     $40.64 (0.55%)       $43.13      $37.85    $40.57          0.2053%
# HYGV     $40.54 (0.72%)       $43.56      $38.43    $40.48          0.1082%
# LKOR     $43.31 (0.90%)       $47.59      $38.16    $43.17          0.3141%
# MBSD     $20.32 (0.34%)       $21.59      $19.72    $20.30          0.0611%
# RAVI     $75.05 (0.05%)       $75.29      $74.07    $75.03          0.0265%
# SKOR     $47.03 (0.45%)       $48.77      $44.75    $46.90          0.2488%
# TDTF     $23.64 (0.36%)       $26.26      $23.20    $23.61          0.0661%
# TDTT     $23.46 (0.21%)       $25.35      $23.18    $23.47          0.0848%
#
#        PRIMARY EXCHANGE      CUSIP TOTAL NET ASSETS  ...  \
# TICKER                                               ...
# BNDC          NYSE Arca  33939L670         $200.78M  ...
# FEHY          NYSE Arca  33939L589           $2.00M  ...
# FEIG          NYSE Arca  33939L571          $38.53M  ...
# HYGV          NYSE Arca  33939L662           $1.17B  ...
# LKOR               CBOE  33939L753          $32.38M  ...
# MBSD          NYSE Arca  33939L779          $73.08M  ...
# RAVI          NYSE Arca  33939L886           $1.00B  ...
# SKOR             NASDAQ  33939L761         $269.69M  ...
# TDTF          NYSE Arca  33939L605         $687.17M  ...
# TDTT          NYSE Arca  33939L506           $1.87B  ...
#
#        WEIGHTED AVG OPTION ADJUSTED SPREAD   INCEPTION WEIGHTED AVG MATURITY  \
# TICKER
# BNDC                             52.43 bps  11/18/2016                   NaN
# FEHY                                   NaN  09/20/2021              0.00 yrs
# FEIG                                   NaN  09/20/2021             11.62 yrs
# HYGV                                   NaN  07/17/2018              5.37 yrs
# LKOR                                   NaN  09/23/2015             24.46 yrs
# MBSD                                   NaN  09/03/2014                   NaN
# RAVI                                   NaN  10/09/2012                   NaN
# SKOR                                   NaN  11/12/2014              5.67 yrs
# TDTF                                   NaN  09/19/2011              5.92 yrs
# TDTT                                   NaN  09/19/2011              3.41 yrs
#
#        NAIC DESIGNATION WEIGHTED AVG COUPON FLOATING RATE FIXED RATE  \
# TICKER
# BNDC                NaN                 NaN           NaN        NaN
# FEHY                NaN                 NaN           NaN        NaN
# FEIG                NaN                 NaN           NaN        NaN
# HYGV                Yes                 NaN           NaN        NaN
# LKOR                NaN                 NaN           NaN        NaN
# MBSD                NaN              0.0353           NaN        NaN
# RAVI                Yes                 NaN        28.35%     50.54%
# SKOR                NaN                 NaN           NaN        NaN
# TDTF                Yes                 NaN           NaN        NaN
# TDTT                Yes                 NaN           NaN        NaN
#
#        ZERO RATE WEIGHTED AVG NOMINAL YIELD  MODIFIED ADJUSTED DURATION
# TICKER
# BNDC         NaN                        NaN                         NaN
# FEHY         NaN                        NaN                         NaN
# FEIG         NaN                        NaN                         NaN
# HYGV         NaN                        NaN                         NaN
# LKOR         NaN                        NaN                         NaN
# MBSD         NaN                        NaN                         NaN
# RAVI      20.92%                        NaN                         NaN
# SKOR         NaN                        NaN                         NaN
# TDTF         NaN                     0.0424                    5.01 yrs
# TDTT         NaN                     0.0454                    2.99 yrs
#
# [10 rows x 32 columns]
