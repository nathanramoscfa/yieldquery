# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import sys
from bots.goldman_sachs import goldman_sachs_bot

# Get DataFrame from vanguard_bot
df = goldman_sachs_bot(return_df=True, headless=True)

# Get the absolute path of the project's root directory
project_dir = os.path.dirname(os.getcwd())

# Change the working directory to the project's root directory
os.chdir(project_dir)

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'goldman_sachs.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading Goldman Sachs ETF yield data...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:57<00:00,  8.89s/it]
# Saving Goldman Sachs ETF yield data to CSV file...
# Done!
#                                                      Name Yield to Maturity  \
# Ticker
# GIGB    Goldman Sachs Access Investment Grade Corporat...            0.0553
# GMUN           Goldman Sachs Community Municipal Bond ETF              3.43
# GSST            Goldman Sachs Access Ultra Short Bond ETF            0.0589
# GBIL           Goldman Sachs Access Treasury 0-1 Year ETF            0.0534
# GSIG    Goldman Sachs Access Investment Grade Corporat...            0.0562
# GEMD    Goldman Sachs Access Emerging Markets USD Bond...            0.0692
# GCOR         Goldman Sachs Access U.S. Aggregate Bond ETF            0.0497
# GTIP    Goldman Sachs Access Inflation Protected USD B...               NaN
# GHYB    Goldman Sachs Access High Yield Corporate Bond...            0.0774
# GVIP                 Goldman Sachs Hedge Industry VIP ETF               NaN
# JUST         Goldman Sachs JUST U.S. Large Cap Equity ETF               NaN
# GTEK         Goldman Sachs Future Tech Leaders Equity ETF               NaN
# GSEU           Goldman Sachs ActiveBeta Europe Equity ETF               NaN
# GSJY            Goldman Sachs ActiveBeta Japan Equity ETF               NaN
# GUSA          Goldman Sachs MarketBeta US 1000 Equity ETF               NaN
# GDEF                   Goldman Sachs Defensive Equity ETF               NaN
# GPAL    Goldman Sachs ActiveBeta Paris-Aligned Climate...               NaN
# GINN                    Goldman Sachs Innovate Equity ETF               NaN
# GSIE    Goldman Sachs ActiveBeta International Equity ETF               NaN
# GCLN      Goldman Sachs Bloomberg Clean Energy Equity ETF               NaN
#
#         As of Date  Weighted Avg Coupon  Effective Duration  \
# Ticker
# GIGB    07-27-2023               0.0385                7.12
# GMUN    07-27-2023                  NaN                 NaN
# GSST    07-27-2023               0.0481                0.61
# GBIL    07-27-2023               0.0001                0.28
# GSIG    07-27-2023               0.0353                2.55
# GEMD    07-27-2023               0.0518                7.34
# GCOR    07-27-2023               0.0275                6.28
# GTIP    07-27-2023                  NaN                6.62
# GHYB    07-27-2023               0.0564                3.57
# GVIP    07-27-2023                  NaN                 NaN
# JUST    07-27-2023                  NaN                 NaN
# GTEK    07-27-2023                  NaN                 NaN
# GSEU    07-27-2023                  NaN                 NaN
# GSJY    07-27-2023                  NaN                 NaN
# GUSA    07-27-2023                  NaN                 NaN
# GDEF    07-27-2023                  NaN                 NaN
# GPAL    07-27-2023                  NaN                 NaN
# GINN    07-27-2023                  NaN                 NaN
# GSIE    07-27-2023                  NaN                 NaN
# GCLN    07-27-2023                  NaN                 NaN
#
#         Weighted Avg Maturity  Option Adjusted Spread  Yield to Worst  \
# Ticker
# GIGB                    11.51                  111.80          0.0552
# GMUN                      NaN                     NaN             NaN
# GSST                     6.64                   64.85          0.0582
# GBIL                     0.29                     NaN          0.0534
# GSIG                     3.35                   81.15          0.0562
# GEMD                    12.80                  257.85          0.0692
# GCOR                    13.65                   39.45          0.0497
# GTIP                     7.10                     NaN             NaN
# GHYB                     4.83                  315.63          0.0772
# GVIP                      NaN                     NaN             NaN
# JUST                      NaN                     NaN             NaN
# GTEK                      NaN                     NaN             NaN
# GSEU                      NaN                     NaN             NaN
# GSJY                      NaN                     NaN             NaN
# GUSA                      NaN                     NaN             NaN
# GDEF                      NaN                     NaN             NaN
# GPAL                      NaN                     NaN             NaN
# GINN                      NaN                     NaN             NaN
# GSIE                      NaN                     NaN             NaN
# GCLN                      NaN                     NaN             NaN
#
#         Average Price        ... Yield to Maturity,capped (YTM,%)  \
# Ticker                       ...
# GIGB            90.68   NaN  ...                              NaN
# GMUN              NaN  Fund  ...                             3.43
# GSST            98.55   NaN  ...                              NaN
# GBIL            98.51   NaN  ...                              NaN
# GSIG            94.96   NaN  ...                              NaN
# GEMD            90.08   NaN  ...                              NaN
# GCOR            89.33   NaN  ...                              NaN
# GTIP            92.49   NaN  ...                              NaN
# GHYB            91.17   NaN  ...                              NaN
# GVIP              NaN   NaN  ...                              NaN
# JUST              NaN   NaN  ...                              NaN
# GTEK              NaN   NaN  ...                              NaN
# GSEU              NaN   NaN  ...                              NaN
# GSJY              NaN   NaN  ...                              NaN
# GUSA              NaN   NaN  ...                              NaN
# GDEF              NaN   NaN  ...                              NaN
# GPAL              NaN   NaN  ...                              NaN
# GINN              NaN   NaN  ...                              NaN
# GSIE              NaN   NaN  ...                              NaN
# GCLN              NaN   NaN  ...                              NaN
#
#        Yield to Worst,capped (YTW,%) % of Green,Social,Sustainability Bonds  \
# Ticker
# GIGB                             NaN                                    NaN
# GMUN                            3.09                                  11.09
# GSST                             NaN                                    NaN
# GBIL                             NaN                                    NaN
# GSIG                             NaN                                    NaN
# GEMD                             NaN                                    NaN
# GCOR                             NaN                                    NaN
# GTIP                             NaN                                    NaN
# GHYB                             NaN                                    NaN
# GVIP                             NaN                                    NaN
# JUST                             NaN                                    NaN
# GTEK                             NaN                                    NaN
# GSEU                             NaN                                    NaN
# GSJY                             NaN                                    NaN
# GUSA                             NaN                                    NaN
# GDEF                             NaN                                    NaN
# GPAL                             NaN                                    NaN
# GINN                             NaN                                    NaN
# GSIE                             NaN                                    NaN
# GCLN                             NaN                                    NaN
#
#            % Green     % Social     % Sustainability P/E Ratio P/B Ratio  \
# Ticker
# GIGB           NaN          NaN                  NaN       NaN       NaN
# GMUN          8.56         2.18                 0.35       NaN       NaN
# GSST           NaN          NaN                  NaN       NaN       NaN
# GBIL           NaN          NaN                  NaN       NaN       NaN
# GSIG           NaN          NaN                  NaN       NaN       NaN
# GEMD           NaN          NaN                  NaN       NaN       NaN
# GCOR           NaN          NaN                  NaN       NaN       NaN
# GTIP           NaN          NaN                  NaN       NaN       NaN
# GHYB           NaN          NaN                  NaN       NaN       NaN
# GVIP           NaN          NaN                  NaN     15.05      3.83
# JUST           NaN          NaN                  NaN     21.72      4.29
# GTEK           NaN          NaN                  NaN     30.25      5.07
# GSEU           NaN          NaN                  NaN     12.65      1.86
# GSJY           NaN          NaN                  NaN     13.74      1.36
# GUSA           NaN          NaN                  NaN     21.86      4.15
# GDEF           NaN          NaN                  NaN     27.84      5.37
# GPAL           NaN          NaN                  NaN     23.04      4.23
# GINN           NaN          NaN                  NaN     22.12      3.21
# GSIE           NaN          NaN                  NaN     12.44      1.72
# GCLN           NaN          NaN                  NaN     19.38      2.63
#
#        Weighted Average Market Cap (Bn) Expected EPS Growth
# Ticker
# GIGB                                NaN                 NaN
# GMUN                                NaN                 NaN
# GSST                                NaN                 NaN
# GBIL                                NaN                 NaN
# GSIG                                NaN                 NaN
# GEMD                                NaN                 NaN
# GCOR                                NaN                 NaN
# GTIP                                NaN                 NaN
# GHYB                                NaN                 NaN
# GVIP                             360.45                 NaN
# JUST                             681.71                 NaN
# GTEK                              35.32               13.84
# GSEU                              93.30                 NaN
# GSJY                              45.04                 NaN
# GUSA                             609.62                 NaN
# GDEF                             568.71                 NaN
# GPAL                             615.56                 NaN
# GINN                             311.68                9.00
# GSIE                              69.19                 NaN
# GCLN                              98.04                8.40
#
# [20 rows x 24 columns]
