# %%
import pandas as pd

# %%
df = pd.read_csv('../data/bond_etf_yield.csv', index_col=0)
df
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0489
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0416
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0544
# MUB                        iShares National Muni Bond ETF             0.0334
# IEF                   iShares 7-10 Year Treasury Bond ETF             0.0404
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0518
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0583
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0565
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0424
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0454
#
#               Date
# Ticker
# AGG     07-27-2023
# TLT     07-27-2023
# LQD     07-27-2023
# MUB     07-27-2023
# IEF     07-27-2023
# ...            ...
# MBSD    07-28-2023
# RAVI    07-28-2023
# SKOR    07-28-2023
# TDTF    07-28-2023
# TDTT    07-28-2023
#
# [331 rows x 3 columns]

# %%
df.sort_values(by='Yield to Maturity', ascending=False).dropna()
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# GMUN           Goldman Sachs Community Municipal Bond ETF             3.4300
# HYEM          VanEck Emerging Markets High Yield Bond ETF             0.1041
# JBBB                                        B-BBB CLO ETF             0.1020
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0975
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0951
# ...                                                   ...                ...
# IBMR         iShares® iBonds® Dec 2029 Term Muni Bond ETF             0.0268
# BBIP         JPMorgan BetaBuilders U.S. TIPS 0-5 Year ETF             0.0253
# TIP                                 iShares TIPS Bond ETF             0.0231
# CWB            SPDR® Bloomberg Convertible Securities ETF             0.0179
# DFIP                   Inflation Protected Securities ETF             0.0178
#
#               Date
# Ticker
# GMUN    07-27-2023
# HYEM    07-28-2023
# JBBB    07-28-2023
# HYGV    07-28-2023
# EMHY    07-27-2023
# ...            ...
# IBMR    07-27-2023
# BBIP    06-30-2023
# TIP     07-27-2023
# CWB     07-27-2023
# DFIP    06-30-2023
#
# [319 rows x 3 columns]

# %%
df.loc['BND']
# Out:
# Name                 Vanguard Total Bond Market ETF
# Yield to Maturity                             0.048
# Date                                     06-30-2023
# Name: BND, dtype: object
