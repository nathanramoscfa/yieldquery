# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from bots.vanguard import vanguard_bot

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/bond_etf_yield.csv', index_col=0)
df
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# AGG                  iShares Core U.S. Aggregate Bond ETF             0.0511
# TLT                    iShares 20+ Year Treasury Bond ETF             0.0450
# LQD     iShares iBoxx $ Investment Grade Corporate Bon...             0.0575
# MUB                        iShares National Muni Bond ETF             0.0362
# IEF                   iShares 7-10 Year Treasury Bond ETF             0.0428
# ...                                                   ...                ...
# MBSD       FLEXSHARES DISCIPLINED DURATION MBS INDEX FUND             0.0567
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             0.0591
# SKOR    FLEXSHARES CREDIT-SCORED US CORPORATE BOND IND...             0.0592
# TDTF    FLEXSHARES IBOXX 5-YEAR TARGET DURATION TIPS I...             0.0448
# TDTT    FLEXSHARES IBOXX 3-YEAR TARGET DURATION TIPS I...             0.0465
#
#         Expected Annualized Std Dev  P/E Ratio  Yield to Volatility  \
# Ticker
# AGG                          0.0681      19.57                 0.75
# TLT                          0.1646      22.22                 0.27
# LQD                          0.0909      17.39                 0.63
# MUB                          0.0400      27.62                 0.90
# IEF                          0.0858      23.36                 0.50
# ...                             ...        ...                  ...
# MBSD                         0.0571      17.64                 0.99
# RAVI                         0.0148      16.92                 3.99
# SKOR                         0.0489      16.89                 1.21
# TDTF                         0.0620      22.32                 0.72
# TDTT                         0.0419      21.51                 1.11
#
#         Yield ZScore        Date
# Ticker
# AGG             0.34  08-18-2023
# TLT             0.71  08-18-2023
# LQD             0.05  08-18-2023
# MUB             1.24  08-18-2023
# IEF             0.84  08-18-2023
# ...              ...         ...
# MBSD            0.00  08-21-2023
# RAVI            0.15  08-21-2023
# SKOR            0.15  08-21-2023
# TDTF            0.72  08-21-2023
# TDTT            0.62  08-21-2023
#
# [318 rows x 7 columns]

# %%
df.sort_values(by='Yield to Maturity', ascending=False).dropna()
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# PGHY        Invesco Global Short Term High Yield Bond ETF             0.1021
# JBBB                                        B-BBB CLO ETF             0.0998
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0998
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0984
# BKLN                              Invesco Senior Loan ETF             0.0963
# ...                                                   ...                ...
# BBIP         JPMorgan BetaBuilders U.S. TIPS 0-5 Year ETF             0.0254
# TIP                                 iShares TIPS Bond ETF             0.0243
# PBTP                 Invesco PureBeta℠ 0-5 Yr US TIPS ETF             0.0227
# CWB            SPDR® Bloomberg Convertible Securities ETF             0.0183
# DFIP                   Inflation Protected Securities ETF             0.0177
#
#         Expected Annualized Std Dev  P/E Ratio  Yield to Volatility  \
# Ticker
# PGHY                         0.0716       9.79                 1.43
# JBBB                         0.0426      10.02                 2.34
# HYGV                         0.0665      10.02                 1.50
# EMHY                         0.0782      10.16                 1.26
# BKLN                         0.0402      10.38                 2.40
# ...                             ...        ...                  ...
# BBIP                         0.0242      39.37                 1.05
# TIP                          0.0617      41.15                 0.39
# PBTP                         0.0370      44.05                 0.61
# CWB                          0.0861      54.64                 0.21
# DFIP                         0.0747      56.50                 0.24
#
#         Yield ZScore        Date
# Ticker
# PGHY            2.76  08-18-2023
# JBBB            2.62  08-21-2023
# HYGV            2.62  08-21-2023
# EMHY            2.53  08-18-2023
# BKLN            2.40  08-18-2023
# ...              ...         ...
# BBIP            1.90  07-31-2023
# TIP             1.97  08-18-2023
# PBTP            2.06  08-18-2023
# CWB             2.33  08-21-2023
# DFIP            2.37  07-31-2023
#
# [318 rows x 7 columns]

# %%
df.loc['HYGV']
# Out:
# Name                           FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...
# Yield to Maturity                                                         0.0998
# Expected Annualized Std Dev                                               0.0665
# P/E Ratio                                                                  10.02
# Yield to Volatility                                                          1.5
# Yield ZScore                                                                2.62
# Date                                                                  08-21-2023
# Name: HYGV, dtype: object
