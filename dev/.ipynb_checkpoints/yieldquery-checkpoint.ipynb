# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
from utils.processing import filtered_df

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/bond_etf_yield.csv', index_col=0)

# %%
df.sort_values(by='Yield to Maturity', ascending=False).dropna()
# Out:
#                                                      Name  Yield to Maturity  \
# Ticker
# JBBB                                        B-BBB CLO ETF             0.0990
# EMHY           iShares J.P. Morgan EM High Yield Bond ETF             0.0984
# HYGV    FLEXSHARES HIGH YIELD VALUE-SCORED BOND INDEX ...             0.0981
# BRLN                     BlackRock Floating Rate Loan ETF             0.0956
# PGHY    Invesco Global ex-US High Yield Corporate Bond...             0.0944
# ...                                                   ...                ...
# BBIP         JPMorgan BetaBuilders U.S. TIPS 0-5 Year ETF             0.0254
# TIP                                 iShares TIPS Bond ETF             0.0243
# PBTP                           Invesco 0-5 Yr US TIPS ETF             0.0223
# DFIP                   Inflation Protected Securities ETF             0.0177
# CWB            SPDR® Bloomberg Convertible Securities ETF             0.0177
#
#         Expected Annualized Std Dev  P/E Ratio  Yield to Volatility  \
# Ticker
# JBBB                         0.0374      10.10                 2.65
# EMHY                         0.0835      10.16                 1.18
# HYGV                         0.0751      10.19                 1.31
# BRLN                         0.0489      10.46                 1.96
# PGHY                         0.0579      10.59                 1.63
# ...                             ...        ...                  ...
# BBIP                         0.0317      39.37                 0.80
# TIP                          0.0656      41.15                 0.37
# PBTP                         0.0416      44.84                 0.54
# DFIP                         0.0772      56.50                 0.23
# CWB                          0.0881      56.50                 0.20
#
#         Yield ZScore        Date
# Ticker
# JBBB            2.68  09-01-2023
# EMHY            2.64  08-18-2023
# HYGV            2.62  09-01-2023
# BRLN            2.46  08-18-2023
# PGHY            2.39  09-01-2023
# ...              ...         ...
# BBIP            1.92  07-31-2023
# TIP             1.99  08-18-2023
# PBTP            2.11  09-01-2023
# DFIP            2.40  07-31-2023
# CWB             2.40  09-01-2023
#
# [314 rows x 7 columns]

# %%
df.loc['AGG']
# Out:
# Name                           iShares Core U.S. Aggregate Bond ETF
# Yield to Maturity                                            0.0511
# Expected Annualized Std Dev                                  0.0748
# P/E Ratio                                                     19.57
# Yield to Volatility                                            0.68
# Yield ZScore                                                   0.31
# Date                                                     08-18-2023
# Name: AGG, dtype: object

# %%
filtered_df(df)
# Out:
#                                                      Name Yield to Maturity  \
# Ticker
# JAAA                                          AAA CLO ETF             7.35%
# VRIG           Invesco Variable Rate Investment Grade ETF             7.12%
# STOT    SPDR® DoubleLine® Short Duration Total Return ...             6.33%
# NEAR                    BlackRock Short Maturity Bond ETF             6.29%
# AGRH    iShares Interest Rate Hedged U.S. Aggregate Bo...             6.17%
# FLRN    SPDR® Bloomberg Investment Grade Floating Rate...             6.11%
# GSY                      Invesco Ultra Short Duration ETF             6.09%
# IBDP         iShares® iBonds® Dec 2024 Term Corporate ETF             5.92%
# VUSB                        Vanguard Ultra-Short Bond ETF             5.80%
# JPST                      JPMorgan Ultra-Short Income ETF             5.80%
# RAVI                   FLEXSHARES ULTRA-SHORT INCOME FUND             5.79%
# GSST            Goldman Sachs Access Ultra Short Bond ETF             5.78%
# BSCO         Invesco BulletShares 2024 Corporate Bond ETF             5.78%
# ICSH                  BlackRock Ultra Short-Term Bond ETF             5.74%
# BSJN    Invesco BulletShares 2023 High Yield Corporate...             5.73%
# FTSM              First Trust Enhanced Short Maturity ETF             5.66%
# USFR               WisdomTree Floating Rate Treasury Fund             5.56%
# TFLO              iShares Treasury Floating Rate Bond ETF             5.55%
# IBDO         iShares® iBonds® Dec 2023 Term Corporate ETF             5.54%
# ULST                 SPDR® SSGA Ultra Short Term Bond ETF             5.44%
# SGOV                  iShares 0-3 Month Treasury Bond ETF             5.37%
# SHV                       iShares Short Treasury Bond ETF             5.34%
# BSCN         Invesco BulletShares 2023 Corporate Bond ETF             5.34%
# IBTE          iShares® iBonds® Dec 2024 Term Treasury ETF             5.33%
# GBIL           Goldman Sachs Access Treasury 0-1 Year ETF             5.13%
# IBTD          iShares® iBonds® Dec 2023 Term Treasury ETF             5.10%
# PVI            Invesco Floating Rate Municipal Income ETF             3.73%
# FUMB       First Trust Ultra Short Duration Municipal ETF             3.63%
# CALY        BlackRock Short-Term California Muni Bond ETF             3.39%
# IBML         iShares® iBonds® Dec 2023 Term Muni Bond ETF             3.27%
#
#        Expected Annualized Std Dev  P/E Ratio  Yield to Volatility  \
# Ticker
# JAAA                         2.12%      13.61                 3.47
# VRIG                         1.79%      14.04                 3.98
# STOT                         1.97%      15.80                 3.21
# NEAR                         1.28%      15.90                 4.91
# AGRH                         1.98%      16.21                 3.12
# FLRN                         2.07%      16.37                 2.95
# GSY                          1.33%      16.42                 4.58
# IBDP                         1.76%      16.89                 3.36
# VUSB                         1.50%      17.24                 3.87
# JPST                         1.65%      17.24                 3.52
# RAVI                         1.51%      17.27                 3.83
# GSST                         1.49%      17.30                 3.88
# BSCO                         1.50%      17.30                 3.85
# ICSH                         1.72%      17.42                 3.34
# BSJN                         1.83%      17.45                 3.13
# FTSM                         1.35%      17.67                 4.19
# USFR                         1.45%      17.99                 3.83
# TFLO                         1.34%      18.02                 4.14
# IBDO                         1.29%      18.05                 4.29
# ULST                         1.82%      18.38                 2.99
# SGOV                         1.87%      18.62                 2.87
# SHV                          1.55%      18.73                 3.45
# BSCN                         1.24%      18.73                 4.31
# IBTE                         1.75%      18.76                 3.05
# GBIL                         1.50%      19.49                 3.42
# IBTD                         1.54%      19.61                 3.31
# PVI                          0.95%      26.81                 3.93
# FUMB                         1.08%      27.55                 3.36
# CALY                         0.76%      29.50                 4.46
# IBML                         1.12%      30.58                 2.92
#
#         Yield ZScore        Date
# Ticker
# JAAA            1.08  09-01-2023
# VRIG            0.94  09-01-2023
# STOT            0.45  09-01-2023
# NEAR            0.42  08-18-2023
# AGRH            0.35  08-18-2023
# FLRN            0.31  09-01-2023
# GSY             0.30  09-01-2023
# IBDP            0.19  08-18-2023
# VUSB            0.12  07-31-2023
# JPST            0.12  09-01-2023
# RAVI            0.11  09-01-2023
# GSST            0.10  09-01-2023
# BSCO            0.10  09-01-2023
# ICSH            0.08  08-18-2023
# BSJN            0.07  09-01-2023
# FTSM            0.03  09-01-2023
# USFR            0.03  09-01-2023
# TFLO            0.04  08-18-2023
# IBDO            0.05  08-18-2023
# ULST            0.11  09-01-2023
# SGOV            0.15  08-18-2023
# SHV             0.17  08-18-2023
# BSCN            0.17  09-01-2023
# IBTE            0.18  08-18-2023
# GBIL            0.30  09-01-2023
# IBTD            0.32  08-18-2023
# PVI             1.18  09-01-2023
# FUMB            1.24  07-31-2023
# CALY            1.39  08-18-2023
# IBML            1.46  08-18-2023
