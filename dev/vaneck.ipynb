# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import sys
from bots.vaneck import vaneck_bot

# Get DataFrame from vanguard_bot
df = vaneck_bot(return_df=True, headless=True)

# Get the absolute path of the project's root directory
project_dir = os.path.dirname(os.getcwd())

# Change the working directory to the project's root directory
os.chdir(project_dir)

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'vaneck.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading VanEck ETF yield data...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 18/18 [06:59<00:00, 23.32s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [01:10<00:00, 23.61s/it]
# Saving VanEck ETF yield data to CSV file...
# Done!
#                                                    Name  Yield to Worst  \
# Ticker
# ANGL            VanEck Fallen Angel High Yield Bond ETF          0.0723
# XMPT                         VanEck CEF Muni Income ETF          0.0684
# CBON                              VanEck China Bond ETF             NaN
# CLOI                                     VanEck CLO ETF          0.0649
# HYEM        VanEck Emerging Markets High Yield Bond ETF          0.1032
# GRNB                              VanEck Green Bond ETF          0.0561
# HYD                          VanEck High Yield Muni ETF          0.0507
# SMI                     VanEck HIP Sustainable Muni ETF          0.0361
# FLTR                        VanEck IG Floating Rate ETF          0.0631
# ITM                        VanEck Intermediate Muni ETF          0.0331
# IHY            VanEck International High Yield Bond ETF          0.0805
# EMLC      VanEck J.P. Morgan EM Local Currency Bond ETF          0.0717
# MLN                                VanEck Long Muni ETF          0.0409
# MBBB    VanEck Moody’s Analytics BBB Corporate Bond ETF          0.0586
# MIG      VanEck Moody’s Analytics IG Corporate Bond ETF          0.0575
# SHYD                   VanEck Short High Yield Muni ETF          0.0472
# SMB                               VanEck Short Muni ETF          0.0324
#
#         Yield to Maturity  As of Date
# Ticker
# ANGL               0.0733  07-28-2023
# XMPT               0.0732  07-28-2023
# CBON               0.0269  07-28-2023
# CLOI               0.0648  07-28-2023
# HYEM               0.1041  07-28-2023
# GRNB               0.0562  07-28-2023
# HYD                0.0524  07-28-2023
# SMI                0.0403  07-28-2023
# FLTR               0.0638  07-28-2023
# ITM                0.0384  07-28-2023
# IHY                0.0815  07-28-2023
# EMLC               0.0724  07-28-2023
# MLN                0.0441  07-28-2023
# MBBB               0.0587  07-28-2023
# MIG                0.0575  07-28-2023
# SHYD               0.0486  07-28-2023
# SMB                0.0330  07-28-2023
