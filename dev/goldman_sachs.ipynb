# %%
import sys
sys.path.insert(0, '..')  # Add the parent directory (project root directory) to the Python path

# %%
import os
import sys
from bots.goldman_sachs import goldman_sachs_bot

# Get DataFrame from vanguard_bot
df = goldman_sachs_bot(return_df=True, headless=True)

# Get the absolute path of the project's root directory
project_dir = os.path.dirname(os.getcwd())

# Change the working directory to the project's root directory
os.chdir(project_dir)

# Now, you can construct the paths to your CSV files relative to the project's root directory
csv_path = os.path.join('data', 'goldman_sachs.csv')

# Save DataFrame to csv
df.to_csv(csv_path)

# Display DataFrame
df
# Out:
# Downloading Goldman Sachs ETF yield data...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [02:24<00:00,  7.22s/it]
# Saving Goldman Sachs ETF yield data to CSV file...
# Done!
#                                                      Name  Yield to Maturity  \
# Ticker
# GIGB    Goldman Sachs Access Investment Grade Corporat...             0.0568
# GMUN           Goldman Sachs Community Municipal Bond ETF                NaN
# GSST            Goldman Sachs Access Ultra Short Bond ETF             0.0579
# GBIL           Goldman Sachs Access Treasury 0-1 Year ETF             0.0524
# GSIG    Goldman Sachs Access Investment Grade Corporat...             0.0566
# GEMD    Goldman Sachs Access Emerging Markets USD Bond...             0.0706
# GCOR         Goldman Sachs Access U.S. Aggregate Bond ETF             0.0507
# GTIP    Goldman Sachs Access Inflation Protected USD B...                NaN
# GHYB    Goldman Sachs Access High Yield Corporate Bond...             0.0790
# GVIP                 Goldman Sachs Hedge Industry VIP ETF                NaN
# JUST         Goldman Sachs JUST U.S. Large Cap Equity ETF                NaN
# GTEK         Goldman Sachs Future Tech Leaders Equity ETF                NaN
# GSEU           Goldman Sachs ActiveBeta Europe Equity ETF                NaN
# GSJY            Goldman Sachs ActiveBeta Japan Equity ETF                NaN
# GUSA          Goldman Sachs MarketBeta US 1000 Equity ETF                NaN
# GDEF                   Goldman Sachs Defensive Equity ETF                NaN
# GPAL    Goldman Sachs ActiveBeta Paris-Aligned Climate...                NaN
# GINN                    Goldman Sachs Innovate Equity ETF                NaN
# GSIE    Goldman Sachs ActiveBeta International Equity ETF                NaN
# GCLN      Goldman Sachs Bloomberg Clean Energy Equity ETF                NaN
#
#         As of Date  Weighted Avg Coupon  Effective Duration  \
# Ticker
# GIGB    08-11-2023               0.0387                7.00
# GMUN    08-11-2023                  NaN                 NaN
# GSST    08-11-2023               0.0490                0.58
# GBIL    08-11-2023               0.0001                0.31
# GSIG    08-11-2023               0.0358                2.60
# GEMD    08-11-2023               0.0519                7.18
# GCOR    08-11-2023               0.0269                6.25
# GTIP    08-11-2023                  NaN                6.76
# GHYB    08-11-2023               0.0565                3.59
# GVIP    08-11-2023                  NaN                 NaN
# JUST    08-11-2023                  NaN                 NaN
# GTEK    08-11-2023                  NaN                 NaN
# GSEU    08-11-2023                  NaN                 NaN
# GSJY    08-11-2023                  NaN                 NaN
# GUSA    08-11-2023                  NaN                 NaN
# GDEF    08-11-2023                  NaN                 NaN
# GPAL    08-11-2023                  NaN                 NaN
# GINN    08-11-2023                  NaN                 NaN
# GSIE    08-11-2023                  NaN                 NaN
# GCLN    08-11-2023                  NaN                 NaN
#
#         Weighted Avg Maturity  Option Adjusted Spread  Yield to Worst  \
# Ticker
# GIGB                    11.42                  117.33          0.0567
# GMUN                      NaN                     NaN             NaN
# GSST                     6.57                   83.48          0.0569
# GBIL                     0.32                     NaN          0.0524
# GSIG                     3.44                   89.40          0.0565
# GEMD                    12.53                  261.22          0.0706
# GCOR                    13.55                   41.50          0.0507
# GTIP                     7.26                     NaN             NaN
# GHYB                     4.81                  331.10          0.0788
# GVIP                      NaN                     NaN             NaN
# JUST                      NaN                     NaN             NaN
# GTEK                      NaN                     NaN             NaN
# GSEU                      NaN                     NaN             NaN
# GSJY                      NaN                     NaN             NaN
# GUSA                      NaN                     NaN             NaN
# GDEF                      NaN                     NaN             NaN
# GPAL                      NaN                     NaN             NaN
# GINN                      NaN                     NaN             NaN
# GSIE                      NaN                     NaN             NaN
# GCLN                      NaN                     NaN             NaN
#
#         Average Price        ... Option Adjusted Duration (yrs)  \
# Ticker                       ...
# GIGB            89.66   NaN  ...                            NaN
# GMUN              NaN  Fund  ...                           3.90
# GSST            98.64   NaN  ...                            NaN
# GBIL            98.35   NaN  ...                            NaN
# GSIG            94.91   NaN  ...                            NaN
# GEMD            89.22   NaN  ...                            NaN
# GCOR            88.39   NaN  ...                            NaN
# GTIP            91.55   NaN  ...                            NaN
# GHYB            90.66   NaN  ...                            NaN
# GVIP              NaN   NaN  ...                            NaN
# JUST              NaN   NaN  ...                            NaN
# GTEK              NaN   NaN  ...                            NaN
# GSEU              NaN   NaN  ...                            NaN
# GSJY              NaN   NaN  ...                            NaN
# GUSA              NaN   NaN  ...                            NaN
# GDEF              NaN   NaN  ...                            NaN
# GPAL              NaN   NaN  ...                            NaN
# GINN              NaN   NaN  ...                            NaN
# GSIE              NaN   NaN  ...                            NaN
# GCLN              NaN   NaN  ...                            NaN
#
#        Yield to Maturity,capped (YTM,%) Yield to Worst,capped (YTW,%)  \
# Ticker
# GIGB                                NaN                           NaN
# GMUN                               3.55                          3.26
# GSST                                NaN                           NaN
# GBIL                                NaN                           NaN
# GSIG                                NaN                           NaN
# GEMD                                NaN                           NaN
# GCOR                                NaN                           NaN
# GTIP                                NaN                           NaN
# GHYB                                NaN                           NaN
# GVIP                                NaN                           NaN
# JUST                                NaN                           NaN
# GTEK                                NaN                           NaN
# GSEU                                NaN                           NaN
# GSJY                                NaN                           NaN
# GUSA                                NaN                           NaN
# GDEF                                NaN                           NaN
# GPAL                                NaN                           NaN
# GINN                                NaN                           NaN
# GSIE                                NaN                           NaN
# GCLN                                NaN                           NaN
#
#        % of Green,Social,Sustainability Bonds     % Green     % Social  \
# Ticker
# GIGB                                      NaN         NaN          NaN
# GMUN                                    11.47        8.94         2.18
# GSST                                      NaN         NaN          NaN
# GBIL                                      NaN         NaN          NaN
# GSIG                                      NaN         NaN          NaN
# GEMD                                      NaN         NaN          NaN
# GCOR                                      NaN         NaN          NaN
# GTIP                                      NaN         NaN          NaN
# GHYB                                      NaN         NaN          NaN
# GVIP                                      NaN         NaN          NaN
# JUST                                      NaN         NaN          NaN
# GTEK                                      NaN         NaN          NaN
# GSEU                                      NaN         NaN          NaN
# GSJY                                      NaN         NaN          NaN
# GUSA                                      NaN         NaN          NaN
# GDEF                                      NaN         NaN          NaN
# GPAL                                      NaN         NaN          NaN
# GINN                                      NaN         NaN          NaN
# GSIE                                      NaN         NaN          NaN
# GCLN                                      NaN         NaN          NaN
#
#            % Sustainability P/E Ratio P/B Ratio  \
# Ticker
# GIGB                    NaN       NaN       NaN
# GMUN                   0.35       NaN       NaN
# GSST                    NaN       NaN       NaN
# GBIL                    NaN       NaN       NaN
# GSIG                    NaN       NaN       NaN
# GEMD                    NaN       NaN       NaN
# GCOR                    NaN       NaN       NaN
# GTIP                    NaN       NaN       NaN
# GHYB                    NaN       NaN       NaN
# GVIP                    NaN     15.41      3.79
# JUST                    NaN     22.57      4.19
# GTEK                    NaN     28.34      4.74
# GSEU                    NaN     12.54      1.84
# GSJY                    NaN     13.81      1.37
# GUSA                    NaN     22.01      4.07
# GDEF                    NaN     26.45      5.06
# GPAL                    NaN     22.69      4.10
# GINN                    NaN     22.88      3.13
# GSIE                    NaN     12.40      1.71
# GCLN                    NaN     18.72      2.52
#
#        Weighted Average Market Cap (Bn)
# Ticker
# GIGB                                NaN
# GMUN                                NaN
# GSST                                NaN
# GBIL                                NaN
# GSIG                                NaN
# GEMD                                NaN
# GCOR                                NaN
# GTIP                                NaN
# GHYB                                NaN
# GVIP                             350.29
# JUST                             647.19
# GTEK                              33.92
# GSEU                              94.44
# GSJY                              44.43
# GUSA                             577.21
# GDEF                             534.22
# GPAL                             572.20
# GINN                             306.53
# GSIE                              69.65
# GCLN                              95.28
#
# [20 rows x 23 columns]
